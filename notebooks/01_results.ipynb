# %% [markdown]
# # Results loader
#
# This notebook reads artefacts written by `python -m src.main`. It does not download data and does not invent metrics.

# %%
from pathlib import Path
import pandas as pd
root = Path('..') if Path('..', 'results').exists() else Path('.')
perf = pd.read_csv(root / 'results' / 'tables' / 'performance.csv')
perf
